# %% [markdown]
# ## Medical Case :- Health Care Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('healthcare_dataset.csv')

# %%
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
data['Test Results'].unique()
# Out:
# array(['Normal', 'Inconclusive', 'Abnormal'], dtype=object)

# %%
# this columns is not import for my data
data.drop(data[['Name','Date of Admission','Doctor','Room Number','Hospital','Discharge Date']],axis=1,inplace=True)

# %% [markdown]
# ## Domain Analyis
# The dataset you provided has 55,500 rows and 9 columns. Here's a domain analysis based on the visible columns:
#
# 1. *Age*: This column likely represents the age of the patients. It is a numerical variable and could be used to analyze age distribution, age-related trends, and age-related medical conditions.
#
# 2. *Gender*: This categorical column represents the gender of the patients (e.g., Male, Female). It can be used to perform gender-based analysis, such as comparing medical conditions or treatment outcomes between genders.
#
# 3. *Blood Type*: This is another categorical column that indicates the blood type of the patients (e.g., A+, B-, O+, etc.). Blood type can sometimes be related to certain medical conditions or can be essential in medical emergencies requiring blood transfusion.
#
# 4. *Medical Condition*: This column represents the medical condition or diagnosis of the patients (e.g., Cancer, Obesity, Diabetes). This variable is critical for analyzing the prevalence of various conditions within the dataset and their correlation with other factors like age, gender, or blood type.
#
# 5. *Insurance Provider*: This categorical column indicates the insurance provider of the patients (e.g., Blue Cross, Medicare, Aetna). It could be useful for analyzing billing amounts or treatment types by different providers.
#
# 6. *Billing Amount*: This numerical column represents the cost of medical services provided to the patients. It could be analyzed to determine the average cost of treatment by medical condition, insurance provider, or admission type.
#
# 7. *Admission Type*: This categorical column shows the type of admission (e.g., Urgent, Emergency, Elective). This could be used to analyze patterns in admissions, such as which medical conditions are most likely to result in emergency admissions.
#
# 8. *Medication*: This column lists the type of medication administered to the patients (e.g., Paracetamol, Ibuprofen, Aspirin). It can be analyzed to see which medications are most commonly prescribed for certain conditions.
#
# 9. *Test Results*: This column represents the outcome of medical tests (e.g., Normal, Inconclusive, Abnormal). It can be analyzed in conjunction with other variables like medical condition, age, and medication to understand the factors that contribute to different test outcomes.
#
# Overall, this dataset provides a comprehensive view of patient demographics, medical conditions, treatments, and outcomes, which could be valuable for various types of healthcare analysis.

# %% [markdown]
# ## Basic check

# %%
data.shape
# Out:
# (55500, 9)

# %%
data.head()
# Out:
#    Age  Gender Blood Type Medical Condition Insurance Provider  \
# 0   30    Male         B-            Cancer         Blue Cross
# 1   62    Male         A+           Obesity           Medicare
# 2   76  Female         A-           Obesity              Aetna
# 3   28  Female         O+          Diabetes           Medicare
# 4   43  Female        AB+            Cancer              Aetna
#
#    Billing Amount Admission Type   Medication  Test Results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive
# 2    27955.096079      Emergency      Aspirin        Normal
# 3    37909.782410       Elective    Ibuprofen      Abnormal
# 4    14238.317814         Urgent   Penicillin      Abnormal

# %%
data.tail()
# Out:
#        Age  Gender Blood Type Medical Condition Insurance Provider  \
# 55495   42  Female         O+            Asthma         Blue Cross
# 55496   61  Female        AB-           Obesity              Cigna
# 55497   38  Female         B+      Hypertension   UnitedHealthcare
# 55498   43    Male         O-         Arthritis           Medicare
# 55499   53  Female         O+         Arthritis              Aetna
#
#        Billing Amount Admission Type  Medication Test Results
# 55495     2650.714952       Elective  Penicillin     Abnormal
# 55496    31457.797307       Elective     Aspirin       Normal
# 55497    27620.764717         Urgent   Ibuprofen     Abnormal
# 55498    32451.092358       Elective   Ibuprofen     Abnormal
# 55499     4010.134172         Urgent   Ibuprofen     Abnormal

# %%
data.isnull().sum()  # There is no NaN values
# Out:
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Insurance Provider    0
# Billing Amount        0
# Admission Type        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
data.info()   # check imformation about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 55500 non-null  int64
#  1   Gender              55500 non-null  object
#  2   Blood Type          55500 non-null  object
#  3   Medical Condition   55500 non-null  object
#  4   Insurance Provider  55500 non-null  object
#  5   Billing Amount      55500 non-null  float64
#  6   Admission Type      55500 non-null  object
#  7   Medication          55500 non-null  object
#  8   Test Results        55500 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.8+ MB

# %%
data.describe()
# Out:
#                 Age  Billing Amount
# count  55500.000000    55500.000000
# mean      51.539459    25539.316097
# std       19.602454    14211.454431
# min       13.000000    -2008.492140
# 25%       35.000000    13241.224652
# 50%       52.000000    25538.069376
# 75%       68.000000    37820.508436
# max       89.000000    52764.276736

# %%
data.describe(include='O')
# Out:
#        Gender Blood Type Medical Condition Insurance Provider Admission Type  \
# count   55500      55500             55500              55500          55500
# unique      2          8                 6                  5              3
# top      Male         A-         Arthritis              Cigna       Elective
# freq    27774       6969              9308              11249          18655
#
#        Medication Test Results
# count       55500        55500
# unique          5            3
# top       Lipitor     Abnormal
# freq        11140        18627

# %%
cat_col=data.select_dtypes(include='O').columns
print(cat_col)
# Out:
# Index(['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
#        'Admission Type', 'Medication', 'Test Results'],
#       dtype='object')

# %%
for i in cat_col:
    print(i,cat_col,data[i].unique())
    print(data[i].value_counts())
    print('*******************************************************************')
# Out:
# Gender Index(['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
#        'Admission Type', 'Medication', 'Test Results'],
#       dtype='object') ['Male' 'Female']
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64
# *******************************************************************
# Blood Type Index(['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
#        'Admission Type', 'Medication', 'Test Results'],
#       dtype='object') ['B-' 'A+' 'A-' 'O+' 'AB+' 'AB-' 'B+' 'O-']
# Blood Type
# A-     6969
# A+     6956
# AB+    6947
# AB-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64
# *******************************************************************
# Medical Condition Index(['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
#        'Admission Type', 'Medication', 'Test Results'],
# ...

# %% [markdown]
# ## Exploratory Date Analyis

# %% [markdown]
# ### univeriant analyis using sweetviz

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
plt.figure(figsize=(25,15))
plotnumber=1
for i in cat_col:
    if plotnumber<=11:
        plt.subplot(5,2,plotnumber)
        sns.barplot(data[i])
        plt.xlabel(i,fontsize=15)
        plt.ylabel('Counts',fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Biavariant Analysis

# %% [markdown]
# ### Checking relationship of all variables with respect to target variable

# %%
plt.figure(figsize=(25,15))
plotnumber=1
for i in data:
    if plotnumber<=11:
        plt.subplot(5,2,plotnumber)
        sns.histplot(data[i],kde=True)
        plt.xlabel(i,fontsize=10)
        plt.ylabel('Count',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Insights
# The image you provided displays multiple histograms and KDE (Kernel Density Estimate) plots from a Jupyter notebook, likely showing distributions of various features in a healthcare dataset. Here’s a general insight based on what I can see:
#
# 1. *Age Distribution:*
#    - The top-left plot seems to represent the distribution of age. The histogram shows a fairly even distribution, indicating that the dataset covers a wide range of age groups.
#
# 2. *Gender Distribution:*
#    - The second row seems to display a plot related to gender. The bars on the histogram are likely indicating a binary distribution, with two peaks representing male and female categories. It suggests that the dataset has a relatively balanced distribution of genders.
#
# 3. *Medical Condition:*
#    - Another plot shows various medical conditions such as cancer, obesity, diabetes, etc. The density curves indicate the frequency of each condition in the dataset. Certain conditions appear more frequently than others.
#
# 4. *Insurance Provider:*
#    - The distribution of different insurance providers is displayed, with labels like Blue Cross, Medicare, Aetna, etc. The dataset might be heavily skewed toward one or a few providers.
#
# 5. *Medical Attention Type:*
#    - This plot might be showing different types of medical attention (e.g., urgent, emergency). The distribution suggests that one type of medical attention is significantly more common.
#
# 6. *Billing Amount:*
#    - The billing amount distribution shows that most of the billing amounts fall within a specific range. It could be skewed, with fewer high-billing cases.
#
# 7. *Medication:*
#    - The last plot might show the distribution of different types of medication prescribed. The density curve suggests a concentration around a few medications.
#
# ### Overall Insights:
# - The dataset seems diverse, covering a range of ages, genders, medical conditions, insurance providers, and billing amounts.
# - Certain features (e.g., medical conditions, medication types) might have a skewed distribution, indicating the prevalence of specific conditions or treatments.
# - The data might be used to analyze patterns related to medical billing, insurance, and healthcare services across different demographics.

# %%
data.duplicated().sum()
# Out:
# 534

# %%
data.drop_duplicates(inplace=True)  # deleated duplicated values

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (54966, 9)

# %%
data.isnull().sum()   ## there is no missing values
# Out:
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Insurance Provider    0
# Billing Amount        0
# Admission Type        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ## Check Outliers

# %%
plt.figure(figsize=(18,18),facecolor='white')
plotnumber=1
for i in data:
    if plotnumber<=18:
        ax=plt.subplot(5,2,plotnumber)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize=15)
        plt.ylabel('Counts',fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
fig , ax = plt.subplots(figsize=(8,5))
sns.boxplot(data=data,ax=ax)
plt.savefig('Boxplot.jpg')
plt.show()

# %%
## Age
Q3 = data['Age'].quantile(0.75)
Q1 = data['Age'].quantile(0.25)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

# %%
len(data.loc[data['Age']>upper_limit]) / len(data)*100
# Out:
# 0.0

# %%
len(data.loc[data['Age']<lower_limit]) / len(data)*100
# Out:
# 0.0

# %%
## Billing Amount
Q3 = data['Billing Amount'].quantile(0.75)
Q1 = data['Billing Amount'].quantile(0.25)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

# %%
len(data.loc[data['Billing Amount']>upper_limit])/len(data)*100
# Out:
# 0.0

# %%
len(data.loc[data['Billing Amount']<lower_limit])/len(data)*100
# Out:
# 0.0

# %%
data.head()
# Out:
#    Age  Gender Blood Type Medical Condition Insurance Provider  \
# 0   30    Male         B-            Cancer         Blue Cross
# 1   62    Male         A+           Obesity           Medicare
# 2   76  Female         A-           Obesity              Aetna
# 3   28  Female         O+          Diabetes           Medicare
# 4   43  Female        AB+            Cancer              Aetna
#
#    Billing Amount Admission Type   Medication  Test Results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive
# 2    27955.096079      Emergency      Aspirin        Normal
# 3    37909.782410       Elective    Ibuprofen      Abnormal
# 4    14238.317814         Urgent   Penicillin      Abnormal

# %%
cat_col
# Out:
# Index(['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
#        'Admission Type', 'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# ### Rename the columns names

# %%
data.rename(columns={'Age':'age',
                     'Gender':'gender',
                     'Blood Type':'blood_type',
                     'Medical Condition':'medical_condition',
                     'Insurance Provider':'insurance_provider',
                     'Billing Amount':'billing_amount',
                     'Admission Type':'admission_type',
                     'Medication':'medication',
                     'Test Results':'test_results'},inplace=True)

# %%
data.head()
# Out:
#    age  gender blood_type medical_condition insurance_provider  \
# 0   30    Male         B-            Cancer         Blue Cross
# 1   62    Male         A+           Obesity           Medicare
# 2   76  Female         A-           Obesity              Aetna
# 3   28  Female         O+          Diabetes           Medicare
# 4   43  Female        AB+            Cancer              Aetna
#
#    billing_amount admission_type   medication  test_results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive
# 2    27955.096079      Emergency      Aspirin        Normal
# 3    37909.782410       Elective    Ibuprofen      Abnormal
# 4    14238.317814         Urgent   Penicillin      Abnormal

# %%
data.shape
# Out:
# (54966, 9)

# %% [markdown]
# ## Encoding using map

# %%
data.columns
# Out:
# Index(['age', 'gender', 'blood_type', 'medical_condition',
#        'insurance_provider', 'billing_amount', 'admission_type', 'medication',
#        'test_results'],
#       dtype='object')

# %%
data.gender.value_counts()
# Out:
# gender
# Male      27496
# Female    27470
# Name: count, dtype: int64

# %%
data.gender=data.gender.map({'Male':1,'Female':0})

# %%
data.head()
# Out:
#    age  gender blood_type medical_condition insurance_provider  \
# 0   30       1         B-            Cancer         Blue Cross
# 1   62       1         A+           Obesity           Medicare
# 2   76       0         A-           Obesity              Aetna
# 3   28       0         O+          Diabetes           Medicare
# 4   43       0        AB+            Cancer              Aetna
#
#    billing_amount admission_type   medication  test_results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive
# 2    27955.096079      Emergency      Aspirin        Normal
# 3    37909.782410       Elective    Ibuprofen      Abnormal
# 4    14238.317814         Urgent   Penicillin      Abnormal

# %%
data.blood_type.value_counts()
# Out:
# blood_type
# A-     6898
# A+     6896
# B+     6885
# AB+    6882
# AB-    6874
# B-     6872
# O+     6855
# O-     6804
# Name: count, dtype: int64

# %%
data.blood_type=data.blood_type.map({'A-':7,'A+':6,'B+':5,'AB+':4,'AB-':3,'B-':2,'O+':1,'O-':0})
data.head(3)
# Out:
#    age  gender  blood_type medical_condition insurance_provider  \
# 0   30       1           2            Cancer         Blue Cross
# 1   62       1           6           Obesity           Medicare
# 2   76       0           7           Obesity              Aetna
#
#    billing_amount admission_type   medication  test_results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive
# 2    27955.096079      Emergency      Aspirin        Normal

# %%
data.medical_condition.value_counts()
# Out:
# medical_condition
# Arthritis       9218
# Diabetes        9216
# Hypertension    9151
# Obesity         9146
# Cancer          9140
# Asthma          9095
# Name: count, dtype: int64

# %%
data.medical_condition=data.medical_condition.map({'Arthritis':5,'Diabetes':4,'Hypertension':3,'Obesity':2,'Cancer':1,'Asthma':0})
data.head(2)
# Out:
#    age  gender  blood_type  medical_condition insurance_provider  \
# 0   30       1           2                  1         Blue Cross
# 1   62       1           6                  2           Medicare
#
#    billing_amount admission_type   medication  test_results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive

# %%
data.insurance_provider.value_counts()
# Out:
# insurance_provider
# Cigna               11139
# Medicare            11039
# UnitedHealthcare    11014
# Blue Cross          10952
# Aetna               10822
# Name: count, dtype: int64

# %%
data.insurance_provider=data.insurance_provider.map({'Cigna':4,'Medicare':3,'UnitedHealthcare':2,'Blue Cross':1,'Aetna':0})
data.head(2)
# Out:
#    age  gender  blood_type  medical_condition  insurance_provider  \
# 0   30       1           2                  1                   1
# 1   62       1           6                  2                   3
#
#    billing_amount admission_type   medication  test_results
# 0    18856.281306         Urgent  Paracetamol        Normal
# 1    33643.327287      Emergency    Ibuprofen  Inconclusive

# %%
data.admission_type.value_counts()
# Out:
# admission_type
# Elective     18473
# Urgent       18391
# Emergency    18102
# Name: count, dtype: int64

# %%
data.admission_type=data.admission_type.map({'Elective':2,'Urgent':1,'Emergency':0})
data.head(2)
# Out:
#    age  gender  blood_type  medical_condition  insurance_provider  \
# 0   30       1           2                  1                   1
# 1   62       1           6                  2                   3
#
#    billing_amount  admission_type   medication  test_results
# 0    18856.281306               1  Paracetamol        Normal
# 1    33643.327287               0    Ibuprofen  Inconclusive

# %%
data.medication.value_counts()
# Out:
# medication
# Lipitor        11038
# Ibuprofen      11023
# Aspirin        10984
# Paracetamol    10965
# Penicillin     10956
# Name: count, dtype: int64

# %%
data.medication=data.medication.map({'Lipitor':4,'Ibuprofen':3,'Aspirin':2,'Paracetamol':1,'Penicillin':0})
data.head(2)
# Out:
#    age  gender  blood_type  medical_condition  insurance_provider  \
# 0   30       1           2                  1                   1
# 1   62       1           6                  2                   3
#
#    billing_amount  admission_type  medication  test_results
# 0    18856.281306               1           1        Normal
# 1    33643.327287               0           3  Inconclusive

# %%
data.test_results.value_counts()
# Out:
# test_results
# Abnormal        18437
# Normal          18331
# Inconclusive    18198
# Name: count, dtype: int64

# %%
data.test_results=data.test_results.map({'Abnormal':2,'Normal':1,'Inconclusive':0})
data.head(2)
# Out:
#    age  gender  blood_type  medical_condition  insurance_provider  \
# 0   30       1           2                  1                   1
# 1   62       1           6                  2                   3
#
#    billing_amount  admission_type  medication  test_results
# 0    18856.281306               1           1             1
# 1    33643.327287               0           3             0

# %%
## their all columns are category to numerical 
data
# Out:
#        age  gender  blood_type  medical_condition  insurance_provider  \
# 0       30       1           2                  1                   1
# 1       62       1           6                  2                   3
# 2       76       0           7                  2                   0
# 3       28       0           1                  4                   3
# 4       43       0           4                  1                   0
# ...    ...     ...         ...                ...                 ...
# 55495   42       0           1                  0                   1
# 55496   61       0           3                  2                   4
# 55497   38       0           5                  3                   2
# 55498   43       1           0                  5                   3
# 55499   53       0           1                  5                   0
#
#        billing_amount  admission_type  medication  test_results
# ...

# %% [markdown]
# ## Check Correlation

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(data.corr(),cmap='rainbow',linewidths=.5,annot=True)
plt.show()

# %% [markdown]
# ## data preprocessing

# %%
data1=data.copy()

# %%
data1.head()
# Out:
#    age  gender  blood_type  medical_condition  insurance_provider  \
# 0   30       1           2                  1                   1
# 1   62       1           6                  2                   3
# 2   76       0           7                  2                   0
# 3   28       0           1                  4                   3
# 4   43       0           4                  1                   0
#
#    billing_amount  admission_type  medication  test_results
# 0    18856.281306               1           1             1
# 1    33643.327287               0           3             0
# 2    27955.096079               0           2             1
# 3    37909.782410               2           3             2
# 4    14238.317814               1           0             2

# %% [markdown]
# ### Scale the data

# %%
data.columns
# Out:
# Index(['age', 'gender', 'blood_type', 'medical_condition',
#        'insurance_provider', 'billing_amount', 'admission_type', 'medication',
#        'test_results'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data1[['age', 'gender', 'blood_type', 'medical_condition',
       'insurance_provider', 'billing_amount', 'admission_type', 'medication']]=scaler.fit_transform(data1[['age', 'gender', 'blood_type', 'medical_condition',
       'insurance_provider', 'billing_amount', 'admission_type', 'medication']])

# %%
data1 # scaling the data
# Out:
#             age    gender  blood_type  medical_condition  insurance_provider  \
# 0     -1.098427  0.999527   -0.658711          -0.882797           -0.716729
# 1      0.533770  0.999527    1.088212          -0.297277            0.698170
# 2      1.247856 -1.000473    1.524943          -0.297277           -1.424179
# 3     -1.200439 -1.000473   -1.095442           0.873764            0.698170
# 4     -0.435347 -1.000473    0.214750          -0.882797           -1.424179
# ...         ...       ...         ...                ...                 ...
# 55495 -0.486353 -1.000473   -1.095442          -1.468318           -0.716729
# 55496  0.482764 -1.000473   -0.221981          -0.297277            1.405619
# 55497 -0.690378 -1.000473    0.651481           0.288244           -0.009280
# 55498 -0.435347  0.999527   -1.532173           1.459285            0.698170
# 55499  0.074715 -1.000473   -1.095442           1.459285           -1.424179
#
# ...

# %% [markdown]
# ## Create X and Y

# %%
X = data1.drop('test_results',axis=1)
y = data1.test_results

# %%
X.head()
# Out:
#         age    gender  blood_type  medical_condition  insurance_provider  \
# 0 -1.098427  0.999527   -0.658711          -0.882797           -0.716729
# 1  0.533770  0.999527    1.088212          -0.297277            0.698170
# 2  1.247856 -1.000473    1.524943          -0.297277           -1.424179
# 3 -1.200439 -1.000473   -1.095442           0.873764            0.698170
# 4 -0.435347 -1.000473    0.214750          -0.882797           -1.424179
#
#    billing_amount  admission_type  medication
# 0       -0.470713       -0.008275   -0.709862
# 1        0.570021       -1.234216    0.704151
# 2        0.169675       -1.234216   -0.002856
# 3        0.870301        1.217667    0.704151
# 4       -0.795732       -0.008275   -1.416869

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    2
# 4    2
# Name: test_results, dtype: int64

# %% [markdown]
# ### Train and Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=56)

# %%
x_train.shape
# Out:
# (43972, 8)

# %%
y_test.shape
# Out:
# (10994,)

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
smote=SMOTE()
x_smote,y_smote=smote.fit_resample(x_train,y_train)
print('Actual Value',Counter(y_train))
print('SMOTE Value',Counter(y_smote))
# Out:
# Actual Value Counter({2: 14779, 1: 14641, 0: 14552})
# SMOTE Value Counter({0: 14779, 1: 14779, 2: 14779})

# %% [markdown]
# ## Create the models

# %% [markdown]
# ## Model -1 Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_smote,y_smote)
dt_predict = dt.predict(x_test)

# %%
## Check Metrics Score
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
accuracy_score(y_test,dt_predict)
# Out:
# 0.8839366927414953

# %%
r2_score(y_test,dt_predict)
# Out:
# 0.6577423145920069

# %%
print(classification_report(y_test,dt_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89      3618
#            1       0.88      0.88      0.88      3698
#            2       0.89      0.88      0.88      3678
#
#     accuracy                           0.88     10994
#    macro avg       0.88      0.88      0.88     10994
# weighted avg       0.88      0.88      0.88     10994

# %% [markdown]
# ## Model -2 Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
random = RandomForestClassifier()
random.fit(x_smote,y_smote)
rand_predict = random.predict(x_test)

# %%
accuracy_score(y_test,rand_predict)
# Out:
# 0.8873021648171731

# %%
r2_score(y_test,rand_predict)
# Out:
# 0.662402611469809

# %%
print(classification_report(y_test,rand_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      3618
#            1       0.89      0.88      0.89      3698
#            2       0.89      0.89      0.89      3678
#
#     accuracy                           0.89     10994
#    macro avg       0.89      0.89      0.89     10994
# weighted avg       0.89      0.89      0.89     10994

# %%
## Model Comparison
df=pd.DataFrame()
df['Model'] = ['Decision Tree','Random Forest']
df['Accuracy'] = [88,89]
df['r2 score'] = [0.66,0.65]
df
# Out:
#            Model  Accuracy  r2 score
# 0  Decision Tree        88      0.66
# 1  Random Forest        89      0.65

# %%
sns.barplot(x='Model',y='Accuracy',data=df)
# Out:
# <Axes: xlabel='Model', ylabel='Accuracy'>
